# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
import pymysql 
pd.set_option('display.max_columns', None)

# %%
db = pymysql.connect(host='localhost', user='root', password='Kumar@2005', database='churning')

# %%
db

# %%
pd.read_sql_query("SELECT * FROM churns", db)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5812\3298777545.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM churns", db)
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7027  6840-RESVB    Male              0     Yes        Yes      24
# 7028  2234-XADUH  Female              0     Yes        Yes      72
# ...

# %%
df=pd.read_sql_query("select *from churns where gender='Female'", db)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5812\2214076178.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query("select *from churns where gender='Female'", db)

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  9237-HQITU  Female              0      No         No       2          Yes
# 2  9305-CDSKC  Female              0      No         No       8          Yes
# 3  6713-OKOMC  Female              0      No         No      10           No
# 4  7892-POOKP  Female              0     Yes         No      28          Yes
# 5  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
# 6  8191-XWSZG  Female              0      No         No      52          Yes
# 7  4190-MFLUW  Female              0     Yes        Yes      10          Yes
# 8  4183-MYFRB  Female              0      No         No      21          Yes
# 9  3638-WEABW  Female              0     Yes         No      58          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# ...
