# %%
d1={"India":'INR',"USA":'USD',"CANADA":'POUND'}
d1
# Out:
# {'India': 'INR', 'USA': 'USD', 'CANADA': 'POUND'}

# %%
d1['USA']
# Out:
# 'USD'

# %%
type (d1)
# Out:
# dict

# %%
len(d1)
# Out:
# 3

# %% [markdown]
# ###replacing values

# %%
d1['USA']='Bucks'

# %%
d1
# Out:
# {'India': 'INR', 'USA': 'Bucks', 'CANADA': 'POUND'}

# %% [markdown]
# inserting new key value

# %%
d1['japan']='YEN'
d1
# Out:
# {'India': 'INR', 'USA': 'Bucks', 'CANADA': 'POUND', 'japan': 'YEN'}

# %%
sorted(d1)
# Out:
# ['CANADA', 'India', 'USA', 'japan']

# %%
d1.values()
# Out:
# dict_values(['INR', 'Bucks', 'POUND', 'YEN'])

# %%
d1.keys()
# Out:
# dict_keys(['India', 'USA', 'CANADA', 'japan'])

# %%
d1.update({'India':'Rs'})
d1
# Out:
# {'India': 'Rs', 'USA': 'Bucks', 'CANADA': 'POUND', 'japan': 'YEN'}

# %% [markdown]
# fetch the profession

# %%
emp_data={1:['shiva',25,'halwai'],
          2:['udit',15,'bawarchi'],
          3:['ram',22,'cook']}

# %%
emp_data[3][2]
# Out:
# 'cook'

# %% [markdown]
# show NA if data is not in dictonary

# %%
emp_data
# Out:
# {1: ['shiva', 25, 'halwai'],
#  2: ['udit', 15, 'bawarchi'],
#  3: ['ram', 22, 'cook']}

# %%
emp_data
# Out:
# {1: ['shiva', 25, 'halwai'],
#  2: ['udit', 15, 'bawarchi'],
#  3: ['ram', 22, 'cook']}
