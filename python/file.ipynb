# %% [markdown]
# open(),read(),close()

# %%
#creating a file
file=open("test.txt","w")
file.close()

# %%
#Reading
file=open('test.txt','r')
for line in file:
    print(line)
# Out:
# fahhhhhhhhhhhhhhhhh
#
# fuck youhhhhhh
#
# wtf
#
# FAHHHHH

# %%
file=open('test.txt','r')
print(file.read())
# Out:
# fahhhhhhhhhhhhhhhhh
# fuck youhhhhhh
# wtf
# FAHHHHH

# %%
file=open('test.txt','r')
print(file.read(26))
# Out:
# fahhhhhhhhhhhhhhhhh
# fuck y

# %%
#writing
file=open('test.txt','w')
file.write("This is the sound of ajay atul")
file.write("\nBring it on baby")
file.close()

# %%
file=open('test.txt','r')
print(file.read())
# Out:
# This is the sound of ajay atul
# Bring it on baby

# %%
#append
with open ('test.txt',"a") as file:
    file.write(' This is the Bhdawa')

# %%
file=open('test.txt','r')
print(file.read())
# Out:
# This is the sound of ajay atul
# Bring it on babyThis is the Bhdawa This is the Bhdawa This is the Bhdawa This is the Bhdawa
