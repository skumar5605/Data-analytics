# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
data={'Year':[1920,1930,1940,1950,1960,1970,1980,1990,2000,2010,2020],'Exchange rate':[65,69,71,64,62,59,72,71,75,78,81]}
df=pd.DataFrame(data,columns=['Year','Exchange rate'])

# %%
df
# Out:
#     Year  Exchange rate
# 0   1920             65
# 1   1930             69
# 2   1940             71
# 3   1950             64
# 4   1960             62
# 5   1970             59
# 6   1980             72
# 7   1990             71
# 8   2000             75
# 9   2010             78
# 10  2020             81

# %%
df.plot(x='Year',y='Exchange rate',kind='bar')
plt.show()

# %%
df.plot(x='Year',y='Exchange rate',kind='area')
plt.show()

# %%
df.plot(x='Year',y='Exchange rate',kind='line')
plt.show()

# %%
df.plot(x='Year',y='Exchange rate',kind='barh')
plt.show()

# %%
df.plot(x='Year',y='Exchange rate',kind='scatter')
plt.show()

# %%
plt.scatter(df['Year'],df['Exchange rate'])

# %%
data={'Tasks':[100,500,300]}
df=pd.DataFrame(data,columns=['Tasks'],index=['pending','ongoing','completed'])
df
# Out:
#            Tasks
# pending      100
# ongoing      500
# completed    300

# %%
df.plot.pie(y='Tasks',figsize=(5,5))
# Out:
# <Axes: ylabel='Tasks'>

# %%
house=pd.read_csv('housing.csv')

# %%
house.housing_median_age.value_counts()
# Out:
# housing_median_age
# 52.0    1273
# 36.0     862
# 35.0     824
# 16.0     771
# 17.0     698
# 34.0     689
# 26.0     619
# 33.0     615
# 18.0     570
# 25.0     566
# 32.0     565
# 37.0     537
# 15.0     512
# 19.0     502
# 27.0     488
# 24.0     478
# 30.0     476
# 28.0     471
# 20.0     465
# 29.0     461
# 31.0     458
# 23.0     448
# 21.0     446
# 14.0     412
# 22.0     399
# 38.0     394
# 39.0     369
# 42.0     368
# 44.0     356
# 43.0     353
# 40.0     304
# 13.0     302
# 41.0     296
# 45.0     294
# 10.0     264
# 11.0     254
# 46.0     245
# 5.0      244
# 12.0     238
# 8.0      206
# 9.0      205
# 47.0     198
# 4.0      191
# 48.0     177
# 7.0      175
# 6.0      160
# 50.0     136
# 49.0     134
# 3.0       62
# 2.0       58
# 51.0      48
# 1.0        4
# Name: count, dtype: int64

# %%
house.housing_median_age.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='housing_median_age'>

# %%
plt.bar(house['housing_median_age'].,house['latitude'].mean(),color='green')
# Out:
# <BarContainer object of 20640 artists>

# %%
plt.title('housing_median_age vs latitude')
# Out:
# Text(0.5, 1.0, 'housing_median_age vs latitude')

# %% [markdown]
# Pie Chart

# %%
lab='javascript','java','python','R'
sizes=[15,30,45,10]
explode_labels=[0,0,0.1,0,]
fig1,ax1=plt.subplots()

ax1.pie(sizes,explode=explode_labels,labels=lab,startangle=90)
ax1.axis('equal')
plt.show()

# %%
house['housing_median_age'].plot.box()
# Out:
# <Axes: >

# %%
house['housing_median_age'].describe()
# Out:
# count    20640.000000
# mean        28.639486
# std         12.585558
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64
