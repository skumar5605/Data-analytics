# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("housing.csv")

# %%
from sklearn.preprocessing import StandardScaler  #standardization
from sklearn.preprocessing import MinMaxScaler   #normalization

# %%
df1 =pd.DataFrame(df,columns=['total_rooms','total_bedrooms'])
df1.head()
# Out:
#    total_rooms  total_bedrooms
# 0        880.0           129.0
# 1       7099.0             0.0
# 2       1467.0           190.0
# 3       1274.0           235.0
# 4       1627.0           280.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_rooms     20640 non-null  float64
#  1   total_bedrooms  20640 non-null  float64
# dtypes: float64(2)
# memory usage: 322.6 KB

# %%
df1['total_bedrooms']=df1['total_bedrooms'].fillna(df1['total_bedrooms'].mean())

# %%
scaler =MinMaxScaler()
normalizinf=scaler.fit_transform(df1)
print(normalizinf)
# Out:
# [[0.02233074 0.02001552]
#  [0.18050257 0.        ]
#  [0.03726029 0.02948022]
#  ...
#  [0.05727657 0.07525213]
#  [0.04725571 0.06346005]
#  [0.07078183 0.09557797]]

# %%
scaler1=StandardScaler()
standardizing=scaler1.fit_transform(df1)
print(standardizing)
# Out:
# [[-0.8048191  -0.9750537 ]
#  [ 2.0458901  -1.28273491]
#  [-0.53574589 -0.82956103]
#  ...
#  [-0.17499526 -0.12594895]
#  [-0.35559977 -0.3072185 ]
#  [ 0.06840827  0.18650252]]
